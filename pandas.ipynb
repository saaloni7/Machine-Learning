# %% [markdown]
# Pandas

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Saloni\Downloads\netflix_titles.csv\netflix_title.csv.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.sample(5) # random 5 sample rows from the dataset
# Out:
#      show_id     type            title           director  \
# 7801   s7802    Movie            Pukar  Rajkumar Santoshi
# 551     s552    Movie  Haseen Dillruba       Vinil Mathew
# 8251   s8252    Movie  The Company Men         John Wells
# 8125   s8126  TV Show      Super Wings                NaN
# 1380   s1381  TV Show        Go Dog Go                NaN
#
#                                                    cast  \
# 7801  Anil Kapoor, Madhuri Dixit, Namrata Shirodkar,...
# 551   Taapsee Pannu, Vikrant Massey, Harshvardhan Ra...
# 8251  Ben Affleck, Chris Cooper, Kevin Costner, Tomm...
# 8125  Luca Padovan, Evan Smolin, Junah Jang, Colin C...
# 1380  Michela Luci, Callum Shoniker, Lyon Smith, Taj...
#
#                                 country        date_added  release_year  \
# 7801                              India     March 1, 2018          2000
# 551                               India      July 2, 2021          2021
# ...

# %%
df. columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %%
df.dtypes
# Out:
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
df.describe() # to see statisical summary of the dataset
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include="object")
# Out:
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_22028\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# ...

# %%
# missing values in the dataset
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# percentage of missing values in the dataset
(df.isnull().sum()/len(df))*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
# duplictes 
df.duplicated().sum() # to check the number of duplicates in the dataset
# Out:
# np.int64(0)

# %%
# remobing duplicates 
df.drop_duplicates(inplace=True) # to remove duplicates from the dataset

# %%
# unique values in the dataset
# df["type"].unique()
# Out:
# <StringArray>
# ['Movie', 'TV Show']
# Length: 2, dtype: str

# %%
# count 
df['type'].nunique()
# Out:
# 2

# %%
df["type"].value_counts()  # to see the count of unique values in the dataset
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="type")
plt.title("Movies vs TV shows on Netflix")
plt.show()

# %%
#finding top ratings
df["rating"].value_counts().head(10) # to see the top 10 ratings in the dataset
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,50))
sns.countplot(data=df, y="rating", order=df["rating"].value_counts().index)
plt.title("Ratings Distributuion on Netflix")
plt.show()
# horiontal bar chart is used to see the distribution of ratings on Netflix

# %%
# movies released every year 
df["release_year"].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["release_year"], bins=30)
plt.title("Movies released every year on Netflix")
plt.xlabel("Release Year")
plt.show()

# %%
#pie chart 
#movie vs tv shows 
counts=df["type"].value_counts()
plt.figure(figsize=(10,5))
plt.pie(
    counts,
    labels=counts.index,
    autopct="%1.1f%%",
    startangle=90,
)
plt.title("Movies vs Tv Shows on Netflix")
plt.show()

# %%
#top counties 
df["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(
    data=df,
    y="country",
    order=df["country"].value_counts().head(10).index
)
plt.title("Top Countries on Netflix")
plt.xlabel("Count")
plt.ylabel("Country")
plt.show()

# %%
#top genres 
genres=(
df["listed_in"]
.str.split(",").
explode().str.strip().value_counts()
)

# %%
#plot
plt.figure(figsize=(10,5))
sns.countplot(
    y=genres,
    order=genres.value_counts().head(10).index
)
plt.title("Top Genres on Netflix")
plt.show()

# %%
# correlation 
numeric=df.select_dtypes(include=np.number)
corr=numeric.corr()

# %%
#heatmap 
plt.figure(figsize=(10,5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Advanced pandas

# %%
df["title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: str

# %%
#type 
type(df["title"])
# Out:
# pandas.Series

# %%
#selecting multiple columns 
df[["title","country","release_year","director"]]
# Out:
#                       title        country  release_year         director
# 0      Dick Johnson Is Dead  United States          2020  Kirsten Johnson
# 1             Blood & Water   South Africa          2021              NaN
# 2                 Ganglands            NaN          2021  Julien Leclercq
# 3     Jailbirds New Orleans            NaN          2021              NaN
# 4              Kota Factory          India          2021              NaN
# ...                     ...            ...           ...              ...
# 8802                 Zodiac  United States          2007    David Fincher
# 8803            Zombie Dumb            NaN          2018              NaN
# 8804             Zombieland  United States          2009  Ruben Fleischer
# 8805                   Zoom  United States          2006     Peter Hewitt
# 8806                 Zubaan          India          2015      Mozez Singh
#
# [8807 rows x 4 columns]

# %% [markdown]
# loc vs iloc
# iloc: integer location , uses row and columns numbers

# %%
#df.iloc[row,column] # to select a specific row and column from the dataset
df.iloc[0]
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                     September 25, 2021
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: 0, dtype: object

# %%
#first row, second column 
df.iloc[0,1]
# Out:
# 'Movie'

# %%
#first 5 rows of the dataset
df.iloc[0:5 ]
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#rows 10-20 
df.iloc[10:21]
# Out:
#    show_id     type                                              title  \
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# 12     s13    Movie                                       Je Suis Karl
# 13     s14    Movie                   Confessions of an Invisible Girl
# 14     s15  TV Show                    Crime Stories: India Detectives
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
# 20     s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
#
#                                          director  \
# 10                                            NaN
# ...

# %%
#first  rows and first 3 columns
df.iloc[:5, :3]
# Out:
#   show_id     type                  title
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory

# %%
#loc : uses label (columns names)
df.loc[:,"title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: str

# %%
#two columns 
df.loc[:,["title","country"]]
# Out:
#                       title        country
# 0      Dick Johnson Is Dead  United States
# 1             Blood & Water   South Africa
# 2                 Ganglands            NaN
# 3     Jailbirds New Orleans            NaN
# 4              Kota Factory          India
# ...                     ...            ...
# 8802                 Zodiac  United States
# 8803            Zombie Dumb            NaN
# 8804             Zombieland  United States
# 8805                   Zoom  United States
# 8806                 Zubaan          India
#
# [8807 rows x 2 columns]

# %%
#rows 10-20 and columns title and country
df.loc[10:20,["title","country"]]
# Out:
#                                                 title                  country
# 10                Vendetta: Truth, Lies and The Mafia                      NaN
# 11                                   Bangkok Breaking                      NaN
# 12                                       Je Suis Karl  Germany, Czech Republic
# 13                   Confessions of an Invisible Girl                      NaN
# 14                    Crime Stories: India Detectives                      NaN
# 15                                  Dear White People            United States
# 16  Europe's Most Dangerous Man: Otto Skorzeny in ...                      NaN
# 17                                    Falsa identidad                   Mexico
# 18                                          Intrusion                      NaN
# 19                                             Jaguar                      NaN
# 20    Monsters Inside: The 24 Faces of Billy Milligan                      NaN

# %%
#rows 100-110, cols :title , dir, country 
df.loc[100:110,["title","director","country"]]
# Out:
#                                         title  \
# 100                   Tobot Galaxy Detectives
# 101                    Untold: Breaking Point
# 102  Countdown: Inspiration4 Mission to Space
# 103                            Shadow Parties
# 104                       Tayo the Little Bus
# 105                          Angamaly Diaries
# 106                                    Bunk'd
# 107                          A Champion Heart
# 108                                 Dive Club
# 109                          La casa de papel
# 110         Money Heist: From Tokyo to Berlin
#
#                                 director        country
# 100                                  NaN            NaN
# 101             Chapman Way, Maclain Way  United States
# 102                          Jason Hehir            NaN
# 103                           Yemi Amodu            NaN
# 104                                  NaN    South Korea
# 105                 Lijo Jose Pellissery          India
# ...

# %%
# filtering data
movies=df[df["type"]=="Movie"]
movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
tv=df[df["type"]=="TV Show"]

# %%
#movies after 2018
df[df["release_year"]>2018]
# Out:
#      show_id     type                        title             director  \
# 0         s1    Movie         Dick Johnson Is Dead      Kirsten Johnson
# 1         s2  TV Show                Blood & Water                  NaN
# 2         s3  TV Show                    Ganglands      Julien Leclercq
# 3         s4  TV Show        Jailbirds New Orleans                  NaN
# 4         s5  TV Show                 Kota Factory                  NaN
# ...      ...      ...                          ...                  ...
# 8516   s8517    Movie    The Spy Who Fell to Earth      Thomas Meadmore
# 8631   s8632    Movie  Trixie Mattel: Moving Parts  Nicholas Zeig-Owens
# 8718   s8719    Movie       Westside vs. the World        Michael Fahey
# 8752   s8753    Movie                     Wish Man          Theo Davies
# 8756   s8757    Movie                    Woodstock        Barak Goodman
#
#                                                    cast         country  \
# ...

# %%
#Movies AND USA
df[
(df["type"]=="Movie") 
& (df["country"]=="United States")
]
# Out:
#      show_id   type                 title          director  \
# 0         s1  Movie  Dick Johnson Is Dead   Kirsten Johnson
# 9        s10  Movie          The Starling    Theodore Melfi
# 27       s28  Movie             Grown Ups      Dennis Dugan
# 28       s29  Movie            Dark Skies     Scott Stewart
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8791   s8792  Movie           Young Adult     Jason Reitman
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
# Movies OR TV shows after 2020 
df[
    (df["type"]=="Movie")|
    (df["release_year"]>2020)
]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8801   s8802    Movie                Zinzana  Majid Al Ansari
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
#isin() filters dataframes and series by cheking if elements exists witin a speicified list , set or dictionary 

df["country"].isin(["United States"
     ,"India",
     "Canada"
     ])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: country, Length: 8807, dtype: bool

# %%
#sorting values : arranging the data in ascending or descending order based on one or more columns
df.sort_values(by="release_year", ascending=False).head(10) # top 10 latest movies and tv shows on netflix
# Out:
#    show_id     type                                            title  \
# 1       s2  TV Show                                    Blood & Water
# 2       s3  TV Show                                        Ganglands
# 3       s4  TV Show                            Jailbirds New Orleans
# 31     s32  TV Show                               Chicago Party Aunt
# 30     s31    Movie                                  Ankahi Kahaniya
# 25     s26  TV Show                             Love on the Spectrum
# 23     s24    Movie     Go! Go! Cory Carson: Chrissy Takes the Wheel
# 20     s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 19     s20  TV Show                                           Jaguar
# 18     s19    Movie                                        Intrusion
#
#                                              director  \
# 1                                                 NaN
# 2                                     Julien Leclercq
# ...

# %%
# String operations : to perform operations on string columns in the dataset instead of using loops 
df[
    df["title"].str.contains("Love")
]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %%
df[
    df["title"].str.startswith("The")
]
# Out:
#      show_id     type                                 title          director  \
# 8         s9  TV Show         The Great British Baking Show   Andy Devonshire
# 9        s10    Movie                          The Starling    Theodore Melfi
# 35       s36    Movie        The Father Who Moves Mountains      Daniel Sandu
# 36       s37    Movie                        The Stronghold    Cédric Jimenez
# 47       s48  TV Show                 The Smart Money Woman    Bunmi Ajakaiye
# ...      ...      ...                                   ...               ...
# 8569   s8570    Movie                    The Young Vagabond        Sze Yu Lau
# 8570   s8571    Movie                       Theater of Life      Peter Svatek
# 8571   s8572    Movie                               Theeram    Saheed Arafath
# 8572   s8573    Movie  Thelonious Monk: Straight, No Chaser  Charlotte Zwerin
# 8573   s8574    Movie                        Theo Who Lived    David Shisgall
#
# ...

# %%
df[
    df["title"].str.endswith("Man")
]
# Out:
#      show_id     type                                              title  \
# 228     s229    Movie                                   The November Man
# 231     s232    Movie                                      The Water Man
# 285     s286    Movie                                    The Railway Man
# 1144   s1145    Movie                                            Yes Man
# 1254   s1255    Movie                                           Rain Man
# 1462   s1463  TV Show                                        Running Man
# 1772   s1773    Movie                                       The 12th Man
# 1903   s1904    Movie                                    An Ordinary Man
# 2978   s2979    Movie                 Kevin Hart: I'm a Grown Little Man
# 3290   s3291    Movie                                       A Single Man
# 3356   s3357  TV Show                                        Nowhere Man
# 3894   s3895    Movie                                    A Fortunate Man
# ...

# %%
# convert to uppercase 
df["title"].str.upper()
# Out:
# 0        DICK JOHNSON IS DEAD
# 1               BLOOD & WATER
# 2                   GANGLANDS
# 3       JAILBIRDS NEW ORLEANS
# 4                KOTA FACTORY
#                 ...
# 8802                   ZODIAC
# 8803              ZOMBIE DUMB
# 8804               ZOMBIELAND
# 8805                     ZOOM
# 8806                   ZUBAAN
# Name: title, Length: 8807, dtype: str

# %%
# lowercase 
df["title"].str.lower()
# Out:
# 0        dick johnson is dead
# 1               blood & water
# 2                   ganglands
# 3       jailbirds new orleans
# 4                kota factory
#                 ...
# 8802                   zodiac
# 8803              zombie dumb
# 8804               zombieland
# 8805                     zoom
# 8806                   zubaan
# Name: title, Length: 8807, dtype: str

# %%
#length 
df["title"].str.len()
# Out:
# 0       20
# 1       13
# 2        9
# 3       21
# 4       12
#         ..
# 8802     6
# 8803    11
# 8804    10
# 8805     4
# 8806     6
# Name: title, Length: 8807, dtype: int64

# %%
# datetime
# Convert the column to datetime before using .dt

df["date_added"] = pd.to_datetime(df["date_added"], errors="coerce")
print("date_added dtype:", df["date_added"].dtype)
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["added_year"] = df["date_added"].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 df["added_year"] = df["date_added"].dt.year
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# ...
